# %% [markdown]
# ### Polymorphism
#
# Ploymorphism is a core concept in Object oriented Programming that allows objects of dofferent classes to be treated as objects of a common superclass. It provides a way to perform a single action in different forms.
# Polymorphism is typically achieved through method overriding and overloading.

# %% [markdown]
# #### Method overrideing
#
# Method overriding allows a child class to provide a specific implementation of a method that is already defined in its parent class.

# %%
## Base class
class Animal:
    @staticmethod
    def speak():
        return f"sound of the animal"
    
# derived class 1
class Dog(Animal):
    @staticmethod
    def speak():
        return f"Woof..."
    
class Cat(Animal):
    @staticmethod
    def speak():
        return f"Meowww..."
    
print(Cat.speak())
print(Dog.speak())
# Out:
# Meowww...
# Woof...

# %%
# can be implemeted in this wayt too
def animal_speak(animal):
    print(animal.speak())
    
dog = Dog()
cat = Cat()
animal_speak(cat)
animal_speak(dog)
# Out:
# Meowww...
# Woof...

# %%
## ploymorphism with functions and methods
# base class
class Shape:
    def area(self):
        return f"Area of the figure"
    
# derived class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
        
    def area(self):
        return self.length * self.width
    
# Derived class 2
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
        
    def area(self):
        return 3.14 * self.radius * self.radius
    
# function that demonstrates polymorphism
def calculate_area(shape):
    print(f'Area of {shape.__class__.__name__} is {shape.area()}')
    
rectangle = Rectangle(5, 4)
circle = Circle(7)

calculate_area(rectangle)
calculate_area(circle)
# Out:
# Area of Rectangle is 20
# Area of Circle is 153.86

# %% [markdown]
# ### Polymorphism with `Abstract Base Class `

# %%
from abc import ABC, abstractmethod

# define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass
    
# derived class
class Car(Vehicle):
    def start_engine(self):
        return 'Car Engine Started'
    
# another derived class
class MotorCycle(Vehicle):
    def start_engine(self):
        return 'Motor Engine Started'
    
# function to demonstrate polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())
    
# instantiation
car = Car()
motor = MotorCycle()

start_vehicle(car)
start_vehicle(motor)
# Out:
# Car Engine Started
# Motor Engine Started
